# %% [markdown]
# ## Cricket Batting Performance Prediction (One Day Internationals)

# %%
from IPython.display import Image
Image(url='https://bhopali2much.files.wordpress.com/2017/05/5f00f-virat-kohli-jab-six-vs-england-1st-odi-2016-video.gif')
# Out:
# <img src="https://bhopali2much.files.wordpress.com/2017/05/5f00f-virat-kohli-jab-six-vs-england-1st-odi-2016-video.gif"/>

# %%
# Libraries

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### Importing Data

# %%
dataset=pd.read_csv("ODI.csv")
dataset.head(5)
# Out:
#   Innings Player Innings Runs Scored Innings Runs Scored Num  \
# 0         JJ Roy                 180                     180
# 1       AD Hales                 171                     171
# 2         JJ Roy                 162                     162
# 3     AJ Strauss                 158                     158
# 4     AJ Strauss                 154                     154
#
#   Innings Minutes Batted  Innings Batted Flag  Innings Not Out Flag  \
# 0                    151                  1.0                   0.0
# 1                    166                  1.0                   0.0
# 2                    172                  1.0                   0.0
# 3                    188                  1.0                   0.0
# 4                    201                  1.0                   0.0
#
#   Innings Balls Faced Innings Boundary Fours Innings Boundary Sixes  \
# 0                 151                     16                      5
# 1                 122                     22                      4
# 2                 118                     13                      3
# 3                 145                     18                      1
# 4                 140                     16                      5
#
#   Innings Batting Strike Rate  ... Innings Overs Bowled Innings Bowled Flag  \
# 0                       119.2  ...                  NaN                 NaN
# 1                      140.16  ...                  NaN                 NaN
# 2                      137.28  ...                  NaN                 NaN
# 3                      108.96  ...                  NaN                 NaN
# 4                         110  ...                  NaN                 NaN
#
#   Innings Maidens Bowled Innings Runs Conceded Innings Wickets Taken  \
# 0                    NaN                   NaN                   NaN
# 1                    NaN                   NaN                   NaN
# 2                    NaN                   NaN                   NaN
# 3                    NaN                   NaN                   NaN
# 4                    NaN                   NaN                   NaN
#
#    4 Wickets  5 Wickets 10 Wickets Innings Wickets Taken Buckets  \
# 0        NaN        NaN        NaN                           NaN
# 1        NaN        NaN        NaN                           NaN
# 2        NaN        NaN        NaN                           NaN
# 3        NaN        NaN        NaN                           NaN
# 4        NaN        NaN        NaN                           NaN
#
#    Innings Economy Rate
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
#
# [5 rows x 28 columns]

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ### Excluding the bowling columns
# Here the bowling columns are eliminated as we are predicting performance of batsman only

# %%
dataset=dataset.iloc[:,0:18]
dataset.head(5)
# Out:
#   Innings Player Innings Runs Scored Innings Runs Scored Num  \
# 0         JJ Roy                 180                     180
# 1       AD Hales                 171                     171
# 2         JJ Roy                 162                     162
# 3     AJ Strauss                 158                     158
# 4     AJ Strauss                 154                     154
#
#   Innings Minutes Batted  Innings Batted Flag  Innings Not Out Flag  \
# 0                    151                  1.0                   0.0
# 1                    166                  1.0                   0.0
# 2                    172                  1.0                   0.0
# 3                    188                  1.0                   0.0
# 4                    201                  1.0                   0.0
#
#   Innings Balls Faced Innings Boundary Fours Innings Boundary Sixes  \
# 0                 151                     16                      5
# 1                 122                     22                      4
# 2                 118                     13                      3
# 3                 145                     18                      1
# 4                 140                     16                      5
#
#   Innings Batting Strike Rate Innings Number  Opposition      Ground  \
# 0                       119.2              2   Australia   Melbourne
# 1                      140.16              1    Pakistan  Nottingham
# 2                      137.28              2   Sri Lanka    The Oval
# 3                      108.96              2       India   Bengaluru
# 4                         110              1  Bangladesh  Birmingham
#
#   Innings Date  Country  50s  100s Innings Runs Scored Buckets
# 0   14-01-2018  England  0.0   1.0                     150-199
# 1   30-08-2016  England  0.0   1.0                     150-199
# 2   29-06-2016  England  0.0   1.0                     150-199
# 3   27-02-2011  England  0.0   1.0                     150-199
# 4   12-07-2010  England  0.0   1.0                     150-199

# %% [markdown]
# ## Dropping duplicates and null values

# %%
dataset=dataset.drop_duplicates()
dataset=dataset.dropna()
dataset.head(5)
# Out:
#   Innings Player Innings Runs Scored Innings Runs Scored Num  \
# 0         JJ Roy                 180                     180
# 1       AD Hales                 171                     171
# 2         JJ Roy                 162                     162
# 3     AJ Strauss                 158                     158
# 4     AJ Strauss                 154                     154
#
#   Innings Minutes Batted  Innings Batted Flag  Innings Not Out Flag  \
# 0                    151                  1.0                   0.0
# 1                    166                  1.0                   0.0
# 2                    172                  1.0                   0.0
# 3                    188                  1.0                   0.0
# 4                    201                  1.0                   0.0
#
#   Innings Balls Faced Innings Boundary Fours Innings Boundary Sixes  \
# 0                 151                     16                      5
# 1                 122                     22                      4
# 2                 118                     13                      3
# 3                 145                     18                      1
# 4                 140                     16                      5
#
#   Innings Batting Strike Rate Innings Number  Opposition      Ground  \
# 0                       119.2              2   Australia   Melbourne
# 1                      140.16              1    Pakistan  Nottingham
# 2                      137.28              2   Sri Lanka    The Oval
# 3                      108.96              2       India   Bengaluru
# 4                         110              1  Bangladesh  Birmingham
#
#   Innings Date  Country  50s  100s Innings Runs Scored Buckets
# 0   14-01-2018  England  0.0   1.0                     150-199
# 1   30-08-2016  England  0.0   1.0                     150-199
# 2   29-06-2016  England  0.0   1.0                     150-199
# 3   27-02-2011  England  0.0   1.0                     150-199
# 4   12-07-2010  England  0.0   1.0                     150-199

# %% [markdown]
# ### There are some special characters in the dataset, replacing those to zero

# %%
dataset=dataset.replace('-', 0)

# %% [markdown]
# # Data Pre-processing

# %% [markdown]
# ### The datatype is object for all the columns, converting it to integer

# %%
dataset.dtypes
# Out:
# Innings Player                  object
# Innings Runs Scored             object
# Innings Runs Scored Num         object
# Innings Minutes Batted          object
# Innings Batted Flag            float64
# Innings Not Out Flag           float64
# Innings Balls Faced             object
# Innings Boundary Fours          object
# Innings Boundary Sixes          object
# Innings Batting Strike Rate     object
# Innings Number                  object
# Opposition                      object
# Ground                          object
# Innings Date                    object
# Country                         object
# 50s                            float64
# 100s                           float64
# Innings Runs Scored Buckets     object
# dtype: object

# %%
# pd.to_numeric( )

dataset['Innings Runs Scored Num'] = pd.to_numeric(dataset['Innings Runs Scored Num']) 

dataset['Innings Minutes Batted']= pd.to_numeric(dataset['Innings Minutes Batted']) 
dataset['Innings Balls Faced']= pd.to_numeric(dataset['Innings Balls Faced']) 

dataset['Innings Boundary Fours']= pd.to_numeric(dataset['Innings Boundary Fours']) 

dataset['Innings Boundary Sixes']= pd.to_numeric(dataset['Innings Boundary Sixes']) 


dataset['Innings Batting Strike Rate']= pd.to_numeric(dataset['Innings Batting Strike Rate'])


dataset['Innings Number']= pd.to_numeric(dataset['Innings Number'])


dataset['50s']= pd.to_numeric(dataset['50s'])

#converting Innings date from object to date
dataset['Innings Date'] = pd.to_datetime(dataset['Innings Date'])

# %% [markdown]
# #### Extracting year from date column. The year column becomes important to see how player performs year wise

# %%
dataset['year'] = pd.DatetimeIndex(dataset['Innings Date']).year
dataset.head()
# Out:
#   Innings Player Innings Runs Scored  Innings Runs Scored Num  \
# 0         JJ Roy                 180                      180
# 1       AD Hales                 171                      171
# 2         JJ Roy                 162                      162
# 3     AJ Strauss                 158                      158
# 4     AJ Strauss                 154                      154
#
#    Innings Minutes Batted  Innings Batted Flag  Innings Not Out Flag  \
# 0                     151                  1.0                   0.0
# 1                     166                  1.0                   0.0
# 2                     172                  1.0                   0.0
# 3                     188                  1.0                   0.0
# 4                     201                  1.0                   0.0
#
#    Innings Balls Faced  Innings Boundary Fours  Innings Boundary Sixes  \
# 0                  151                      16                       5
# 1                  122                      22                       4
# 2                  118                      13                       3
# 3                  145                      18                       1
# 4                  140                      16                       5
#
#    Innings Batting Strike Rate  Innings Number  Opposition      Ground  \
# 0                       119.20               2   Australia   Melbourne
# 1                       140.16               1    Pakistan  Nottingham
# 2                       137.28               2   Sri Lanka    The Oval
# 3                       108.96               2       India   Bengaluru
# 4                       110.00               1  Bangladesh  Birmingham
#
#   Innings Date  Country  50s  100s Innings Runs Scored Buckets  year
# 0   2018-01-14  England  0.0   1.0                     150-199  2018
# 1   2016-08-30  England  0.0   1.0                     150-199  2016
# 2   2016-06-29  England  0.0   1.0                     150-199  2016
# 3   2011-02-27  England  0.0   1.0                     150-199  2011
# 4   2010-12-07  England  0.0   1.0                     150-199  2010

# %% [markdown]
# ### Extracting country name on the basis of grounds Example: Melbourne(M.C.G) is in Australia so the  country_played will be Australia

# %%
# CountryWise


cities=pd.read_csv("worldcities.csv")
cities=cities.iloc[:,0:2]
cities=cities.dropna()
cities.head(5)
# Out:
#             Ground    country
# 0        Melbourne  Australia
# 2       Kennington    England
# 4           Sydney  Australia
# 6       Manchester    England
# 8  St. John's Wood    England

# %%
# merging cities dataframe with dataset
mergedDf = dataset.merge(cities, on='Ground')
dataset=mergedDf.drop_duplicates()
dataset = dataset.rename(columns={'country': 'Country_Played'})
dataset.head(5)
# Out:
#    Innings Player Innings Runs Scored  Innings Runs Scored Num  \
# 0          JJ Roy                 180                      180
# 1  PD Collingwood                120*                      120
# 2      JWA Taylor                 98*                       98
# 3         JE Root                 91*                       91
# 4    KP Pietersen                  82                       82
#
#    Innings Minutes Batted  Innings Batted Flag  Innings Not Out Flag  \
# 0                     151                  1.0                   0.0
# 1                     222                  1.0                   1.0
# 2                     126                  1.0                   1.0
# 3                     186                  1.0                   1.0
# 4                     143                  1.0                   0.0
#
#    Innings Balls Faced  Innings Boundary Fours  Innings Boundary Sixes  \
# 0                  151                      16                       5
# 1                  133                       7                       1
# 2                   90                      11                       2
# 3                  110                       5                       0
# 4                   91                       4                       3
#
#    Innings Batting Strike Rate  Innings Number Opposition     Ground  \
# 0                       119.20               2  Australia  Melbourne
# 1                        90.22               2  Australia  Melbourne
# 2                       108.88               2  Australia  Melbourne
# 3                        82.72               2  Australia  Melbourne
# 4                        90.10               1  Australia  Melbourne
#
#   Innings Date  Country  50s  100s Innings Runs Scored Buckets  year  \
# 0   2018-01-14  England  0.0   1.0                     150-199  2018
# 1   2007-09-02  England  0.0   1.0                     100-149  2007
# 2   2015-02-14  England  1.0   0.0                       50-99  2015
# 3   2018-01-14  England  1.0   0.0                       50-99  2018
# 4   2007-12-01  England  1.0   0.0                       50-99  2007
#
#   Country_Played
# 0      Australia
# 1      Australia
# 2      Australia
# 3      Australia
# 4      Australia

# %%
#Continent played in
dataset['continent'] = np.where( (dataset['Country_Played']=='India') |\
                                (dataset['Country_Played']=='Sri Lanka')|\
                                (dataset['Country_Played']=='United Arab Emirates')|\
                                (dataset['Country_Played']=='Bangladesh')| \
                                (dataset['Country_Played']=='Pakistan'),\
                                'Asia', 'Outside Asia')
dataset.head(2)
# Out:
#    Innings Player Innings Runs Scored  Innings Runs Scored Num  \
# 0          JJ Roy                 180                      180
# 1  PD Collingwood                120*                      120
#
#    Innings Minutes Batted  Innings Batted Flag  Innings Not Out Flag  \
# 0                     151                  1.0                   0.0
# 1                     222                  1.0                   1.0
#
#    Innings Balls Faced  Innings Boundary Fours  Innings Boundary Sixes  \
# 0                  151                      16                       5
# 1                  133                       7                       1
#
#    Innings Batting Strike Rate  ...  Opposition     Ground Innings Date  \
# 0                       119.20  ...   Australia  Melbourne   2018-01-14
# 1                        90.22  ...   Australia  Melbourne   2007-09-02
#
#    Country  50s  100s  Innings Runs Scored Buckets  year  Country_Played  \
# 0  England  0.0   1.0                      150-199  2018       Australia
# 1  England  0.0   1.0                      100-149  2007       Australia
#
#       continent
# 0  Outside Asia
# 1  Outside Asia
#
# [2 rows x 21 columns]

# %% [markdown]
# ## Writing to excel file

# %%
from pandas import ExcelWriter

writer = ExcelWriter('CLeaned_data.xlsx')
dataset.to_excel(writer,'Sheet1')
writer.save()
